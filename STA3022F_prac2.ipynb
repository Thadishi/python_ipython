# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd, csv
# %matplotlib inline

# %%
eurojobs = pd.read_csv("/Users/thabokopane/Documents/STA3022F/practicals/prac2/Eurojobs.csv")

# %%
eurojobs
# Out:
#      Agr  Min   Man   PS   Con    SI   Fin   SPS   TC
# 0    3.3  0.9  27.6  0.9   8.2  19.1   6.2  26.6  7.2
# 1    9.2  0.1  21.8  0.6   8.3  14.6   6.5  32.2  7.1
# 2   10.8  0.8  27.5  0.9   8.9  16.8   6.0  22.6  5.7
# 3    6.7  1.3  35.8  0.9   7.3  14.4   5.0  22.3  6.1
# 4   23.2  1.0  20.7  1.3   7.5  16.8   2.8  20.8  6.1
# 5   15.9  0.6  27.6  0.5  10.0  18.1   1.6  20.1  5.7
# 6    7.7  3.1  30.8  0.8   9.2  18.5   4.6  19.2  6.2
# 7    6.3  0.1  22.5  1.0   9.9  18.0   6.8  28.5  6.8
# 8    2.7  1.4  30.2  1.4   6.9  16.9   5.7  28.3  6.4
# 9   12.7  1.1  30.2  1.4   9.0  16.8   4.9  16.8  7.0
# 10  13.0  0.4  25.9  1.3   7.4  14.7   5.5  24.3  7.6
# 11  41.4  0.6  17.6  0.6   8.1  11.5   2.4  11.0  6.7
# 12   9.0  0.5  22.4  0.8   8.6  16.9   4.7  27.6  9.4
# 13  27.8  0.3  24.5  0.6   8.4  13.3   2.7  16.7  5.7
# 14  22.9  0.8  28.5  0.7  11.5   9.7   8.5  11.8  5.5
# 15   6.1  0.4  25.9  0.8   7.2  14.4   6.0  32.4  6.8
# ...

# %% [markdown]
# We are producing a scatter matrix of the each pair

# %%
pd.plotting.scatter_matrix(eurojobs, alpha=0.3, figsize=(14,10), diagonal='kde');
plt.show()

# %%
from sklearn import decomposition


pca = decomposition.PCA()

euro_pca = pca.fit_transform(eurojobs)

pca.explained_variance_ratio_
# Out:
# array([  8.15783578e-01,   1.17482748e-01,   4.08817874e-02,
#          1.51602379e-02,   6.56856714e-03,   2.81204052e-03,
#          1.13135967e-03,   1.74541717e-04,   5.13996042e-06])

# %%
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('number of components')
plt.ylabel('cumulative explained ')
plt.show()

# %%
comps = pd.DataFrame(pca.components_)
comps
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.891758  0.001923 -0.271271 -0.008388 -0.049594 -0.191798 -0.031129
# 1  0.006827 -0.092347 -0.770269 -0.012016 -0.068989  0.234417  0.130082
# 2  0.118467  0.079379  0.184679 -0.006768 -0.077313 -0.579613 -0.469970
# 3 -0.096767 -0.010156 -0.010401  0.018142 -0.082926 -0.607609  0.781193
# 4  0.180044 -0.001122  0.336000 -0.002460 -0.724262  0.265863  0.121062
# 5 -0.152626  0.456361 -0.200931  0.230864 -0.558357 -0.021572 -0.055282
# 6 -0.091621  0.766470 -0.161983  0.062937  0.194295 -0.087935 -0.079977
# 7  0.068678  0.290464  0.074118 -0.909183 -0.004458  0.104436  0.122755
# 8  0.335411  0.323961  0.337463  0.339898  0.325327  0.336653  0.334362
#
#           7         8
# 0 -0.298046 -0.045364
# 1  0.566777  0.009888
# 2  0.597745  0.159415
# 3  0.048337 -0.037835
# 4  0.235916 -0.434890
# 5 -0.247861  0.545939
# 6 -0.004544 -0.567476
# 7  0.052137  0.223814
# 8  0.332364  0.334215

# %%
from seaborn import heatmap

heatmap(comps)
