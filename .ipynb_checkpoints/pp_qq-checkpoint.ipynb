# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd, csv
# %matplotlib inline

# %%
pythonData = pd.read_table("/Users/thabokopane/Documents/STA3030F/projects/project3/data_py.txt")
data = np.genfromtxt("/Users/thabokopane/Documents/STA3030F/projects/project3/data_y.txt")

# %%
pythonData
# Out:
#     Year    Flow  ln(flow)  ln(a+(xi/B)^(a*theta))      F(x)      f(x)
# 0   1936  192.48  5.259992                0.482017  0.535682  0.004435
# 1   1937  303.91  5.716732                1.645700  0.824051  0.001349
# 2   1938  301.26  5.707974                1.623253  0.820427  0.001386
# 3   1939  135.87  4.911699               -0.386127  0.220921  0.006173
# 4   1940  126.52  4.840400               -0.559895  0.164374  0.005868
# 5   1941  474.25  6.161735                2.789410  0.940332  0.000314
# 6   1942  297.17  5.694304                1.588226  0.814638  0.001445
# 7   1943  196.47  5.280510                0.533860  0.553025  0.004259
# 8   1944  327.64  5.791915                1.838526  0.852579  0.001068
# 9   1945  261.34  5.565822                1.259465  0.751860  0.002107
# 10  1946   96.26  4.567053               -1.205157  0.028848  0.002581
# 11  1947  160.52  5.078419                0.026153  0.371226  0.005813
# ...

# %%
plt.scatter(pythonData['Flow'], pythonData['f(x)'], label='function')
plt.show()

# %%
data[0,,:]
